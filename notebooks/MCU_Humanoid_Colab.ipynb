# %% [markdown]
# # MCU Humanoid Colab
#
# Upload the `mcu_humanoid_colab` folder to `/content` before running these cells.

# %%
from pathlib import Path

PROJECT_DIR = Path('/content/mcu_humanoid_colab')
assert PROJECT_DIR.exists(), f'Missing project folder: {PROJECT_DIR}'
print(PROJECT_DIR)

# %%
# %cd /content/mcu_humanoid_colab
# !pip install -r requirements.txt

# %%
# !python scripts/run_experiment.py --config configs/smoke.json --output results/smoke.json

# %%
import json
from pathlib import Path

result_path = Path('results/smoke.json')
print(json.loads(result_path.read_text()))

# %%
# !python scripts/run_experiment.py --config configs/default.json --output results/default.json
